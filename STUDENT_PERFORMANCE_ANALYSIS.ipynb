# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaurav-29-eng/Anudip/blob/main/STUDENT_PERFORMANCE_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c7dcf902-dea8-474f-a3e2-9b5faef34908" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7dcf902-dea8-474f-a3e2-9b5faef34908">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("student.csv")

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        4   0  11  11
# ...

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [5 rows x 33 columns]

# %%
df.tail(10)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 639     MS   M   19       R     GT3       T     1     1     other  services
# 640     MS   M   18       R     GT3       T     4     2     other     other
# 641     MS   F   18       R     GT3       T     2     2   at_home     other
# 642     MS   F   17       U     GT3       T     4     3   teacher     other
# 643     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# ...

# %%
df.shape
# Out:
# (649, 33)

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
df.sample()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob   Fjob  ...  \
# 235     GP   F   17       U     GT3       T     1     1  at_home  other  ...
#
#     famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 235      4        3      4     1     1      5       12  12  12  12
#
# [1 rows x 33 columns]

# %%
df.sample(15)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 68      GP   F   15       R     LE3       T     2     2   health  services
# 510     MS   F   17       R     GT3       T     2     2    other     other
# 188     GP   F   16       U     LE3       T     3     3    other     other
# 630     MS   F   18       R     LE3       T     4     4    other     other
# 171     GP   M   16       R     GT3       T     2     2  at_home     other
# 1       GP   F   17       U     GT3       T     1     1  at_home     other
# 401     GP   M   18       U     GT3       T     4     3  teacher     other
# 223     GP   F   17       R     GT3       T     4     3  teacher     other
# 385     GP   F   18       U     GT3       T     2     2  at_home     other
# 224     GP   F   19       U     GT3       T     3     3    other     other
# 488     MS   F   19       U     GT3       T     1     1  at_home  services
# ...

# %%
df.isnull()
# Out:
#      school    sex    age  address  famsize  Pstatus   Medu   Fedu   Mjob  \
# 0     False  False  False    False    False    False  False  False  False
# 1     False  False  False    False    False    False  False  False  False
# 2     False  False  False    False    False    False  False  False  False
# 3     False  False  False    False    False    False  False  False  False
# 4     False  False  False    False    False    False  False  False  False
# ..      ...    ...    ...      ...      ...      ...    ...    ...    ...
# 644   False  False  False    False    False    False  False  False  False
# 645   False  False  False    False    False    False  False  False  False
# 646   False  False  False    False    False    False  False  False  False
# 647   False  False  False    False    False    False  False  False  False
# 648   False  False  False    False    False    False  False  False  False
#
#       Fjob  ...  famrel  freetime  goout   Dalc   Walc  health  absences  \
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 644    False
# 645    False
# 646    False
# 647    False
# 648    False
# Length: 649, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Unique values

# %%
df["school"].unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %% [markdown]
# Number of unique values

# %%
df["school"].nunique()
# Out:
# 2

# %% [markdown]
# Count frequency.

# %%
df["sex"].value_counts()
# Out:
# sex
# F    383
# M    266
# Name: count, dtype: int64

# %% [markdown]
# Selecting columns

# %%
df["age"]
# Out:
# 0      18
# 1      17
# 2      15
# 3      15
# 4      16
#        ..
# 644    19
# 645    18
# 646    18
# 647    17
# 648    18
# Name: age, Length: 649, dtype: int64

# %% [markdown]
# Selecting multiple columns

# %%
df[["age", "G3"]]
# Out:
#      age  G3
# 0     18  11
# 1     17  11
# 2     15  12
# 3     15  14
# 4     16  13
# ..   ...  ..
# 644   19  10
# 645   18  16
# 646   18   9
# 647   17  10
# 648   18  11
#
# [649 rows x 2 columns]

# %% [markdown]
# FILERING DATA

# %% [markdown]
# Students with age > 18:

# %%
df[df["age"] > 18]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 127     GP   F   19       U     GT3       T     0     1   at_home     other
# 166     GP   M   19       U     GT3       T     3     2  services   at_home
# 224     GP   F   19       U     GT3       T     3     3     other     other
# 279     GP   M   22       U     GT3       T     3     1  services  services
# 290     GP   F   19       U     GT3       T     2     2  services  services
# 295     GP   M   19       U     LE3       A     4     3  services   at_home
# 299     GP   F   20       R     GT3       T     2     1     other     other
# 311     GP   F   19       U     GT3       T     3     3     other  services
# 322     GP   F   19       R     GT3       T     3     2  services  services
# 341     GP   F   19       U     GT3       T     4     4    health     other
# 350     GP   M   19       R     LE3       T     2     1   at_home  services
# ...

# %% [markdown]
# Students scoring above 15:

# %%
df[df["G3"] > 15]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 15      GP   F   16       U     GT3       T     4     4    health     other
# 47      GP   M   16       U     GT3       T     4     3    health  services
# 51      GP   F   15       U     LE3       T     4     2    health     other
# 57      GP   M   15       U     GT3       T     4     4   teacher    health
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 630     MS   F   18       R     LE3       T     4     4     other     other
# 634     MS   F   18       U     GT3       T     3     3     other     other
# 636     MS   M   18       U     GT3       T     4     4   teacher   teacher
# 638     MS   M   17       U     GT3       T     2     3     other  services
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
#
# ...

# %% [markdown]
# Highest final marks.

# %%
df["G3"].max()
# Out:
# 19

# %% [markdown]
# Lowest final marks

# %%
df["G3"].min()
# Out:
# 0

# %% [markdown]
# Average marks

# %%
df["G3"].mean()
# Out:
# np.float64(11.906009244992296)

# %% [markdown]
# Middle Value

# %%
df["G3"].median()
# Out:
# 12.0

# %% [markdown]
# Ascending

# %%
df.sort_values(by="G3")
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 603     MS   F   18       R     LE3       A     4     2   teacher     other
# 605     MS   F   19       U     GT3       T     1     1   at_home  services
# 597     MS   F   18       R     GT3       T     2     2   at_home     other
# 610     MS   F   19       R     GT3       A     1     1   at_home   at_home
# 626     MS   F   18       R     GT3       T     4     4     other   teacher
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 314     GP   M   17       R     GT3       T     1     2   at_home   at_home
# 416     GP   M   17       U     LE3       A     3     2     other     other
# 606     MS   F   17       U     GT3       T     4     2   teacher     other
# 338     GP   F   17       R     LE3       T     3     1  services     other
# 636     MS   M   18       U     GT3       T     4     4   teacher   teacher
#
# ...

# %% [markdown]
# Descending

# %%
df.sort_values(by="G3", ascending=False)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 636     MS   M   18       U     GT3       T     4     4   teacher   teacher
# 338     GP   F   17       R     LE3       T     3     1  services     other
# 596     MS   F   17       U     GT3       T     4     2     other     other
# 113     GP   M   15       U     LE3       T     4     2   teacher     other
# 617     MS   F   18       U     LE3       T     1     1   at_home  services
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 583     MS   F   18       R     GT3       T     2     2     other     other
# 610     MS   F   19       R     GT3       A     1     1   at_home   at_home
# 605     MS   F   19       U     GT3       T     1     1   at_home  services
# 603     MS   F   18       R     LE3       A     4     2   teacher     other
# 626     MS   F   18       R     GT3       T     4     4     other   teacher
#
# ...

# %% [markdown]
# Locate value for 10th row

# %%
df.loc[10]
# Out:
# school                GP
# sex                    F
# age                   15
# address                U
# famsize              GT3
# Pstatus                T
# Medu                   4
# Fedu                   4
# Mjob             teacher
# Fjob              health
# reason        reputation
# guardian          mother
# traveltime             1
# studytime              2
# failures               0
# schoolsup             no
# famsup               yes
# paid                  no
# activities            no
# nursery              yes
# higher               yes
# internet             yes
# romantic              no
# famrel                 3
# freetime               3
# goout                  3
# Dalc                   1
# Walc                   2
# health                 2
# absences               2
# G1                    14
# G2                    14
# G3                    14
# Name: 10, dtype: object

# %%
df.rename(columns={"G3":"Final Marks"})
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df.rename(columns={"G1":"Unit Test Marks"})
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df.rename(columns={"G2":"Mid Sem Marks"})
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df["Average"]=(df["G1"]+df["G2"]+df["G3"])/3

# %% [markdown]
# Above code generated a temporary dataset from the available dataset and has included average column in it and hence head() displays the average column from the new dataset

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3    Average
# 0        3     4     1     1       3        4   0  11  11   7.333333
# 1        3     3     1     1       3        2   9  11  11  10.333333
# 2        3     2     2     3       3        6  12  13  12  12.333333
# 3        2     2     1     1       5        0  14  14  14  14.000000
# 4        3     2     1     2       5        0  11  13  13  12.333333
#
# [5 rows x 34 columns]

# %%
df["Total Marks"]=(df["G1"]+df["G2"]+df["G3"])

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   goout Dalc  Walc  health  absences  G1  G2  G3    Average Total Marks
# 0     4    1     1       3         4   0  11  11   7.333333          22
# 1     3    1     1       3         2   9  11  11  10.333333          31
# 2     2    2     3       3         6  12  13  12  12.333333          37
# 3     2    1     1       5         0  14  14  14  14.000000          42
# 4     2    1     2       5         0  11  13  13  12.333333          37
#
# [5 rows x 35 columns]

# %%
df.drop("Average",axis=1)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# DELETE DUPLICATES.

# %%
df.drop_duplicates()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df.isnull().sum()
# Out:
# school         0
# sex            0
# age            0
# address        0
# famsize        0
# Pstatus        0
# Medu           0
# Fedu           0
# Mjob           0
# Fjob           0
# reason         0
# guardian       0
# traveltime     0
# studytime      0
# failures       0
# schoolsup      0
# famsup         0
# paid           0
# activities     0
# nursery        0
# higher         0
# internet       0
# romantic       0
# famrel         0
# freetime       0
# goout          0
# Dalc           0
# Walc           0
# health         0
# absences       0
# G1             0
# G2             0
# G3             0
# Average        0
# Total Marks    0
# dtype: int64

# %% [markdown]
# Remove Null Values

# %%
df.dropna()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# Replace null values with 0

# %%
df.fillna(0)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# FIND THE STUDENTS WHO STUDY MORE THAN 3 HOURS.

# %%
studytime = df[df["studytime"] > 3]
studytime
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 47      GP   M   16       U     GT3       T     4     3    health  services
# 66      GP   M   15       U     GT3       A     4     4     other  services
# 67      GP   F   16       U     GT3       T     3     1  services     other
# 69      GP   F   15       R     LE3       T     3     1     other     other
# 70      GP   M   16       U     GT3       T     3     1     other     other
# 71      GP   M   15       U     GT3       T     4     2     other     other
# 76      GP   M   15       U     GT3       T     4     0   teacher     other
# 77      GP   F   16       U     GT3       T     2     2     other     other
# 94      GP   M   15       U     LE3       T     2     2  services    health
# 95      GP   F   15       R     GT3       T     1     1   at_home     other
# 105     GP   F   15       U     GT3       A     3     3     other    health
# ...

# %% [markdown]
# FIND THE STUDENTS WITH INTERNET

# %%
internet = df[df["internet"] == "yes"]
internet
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 643     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# FIND THE STUDENTS WITHOUT INTERNET

# %%
nointernet = df[df["internet"] == "no"]
nointernet
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 4       GP   F   16       U     GT3       T     3     3    other     other
# 7       GP   F   17       U     GT3       A     4     4    other   teacher
# 17      GP   F   16       U     GT3       T     3     3    other     other
# 35      GP   F   15       U     GT3       T     2     3    other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 628     MS   F   17       U     GT3       T     2     2    other   at_home
# 639     MS   M   19       R     GT3       T     1     1    other  services
# 640     MS   M   18       R     GT3       T     4     2    other     other
# 641     MS   F   18       R     GT3       T     2     2  at_home     other
# 646     MS   F   18       U     GT3       T     1     1    other     other
#
# ...

# %% [markdown]
# FIND THE STUDENTS WHOSE ATTENDANCE IS POOR (>10)

# %%
attendance = df[df["absences"] < 10]
attendance
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# FIND THE TOP 3 STUDENTS

# %%
top3 = df.nlargest(3, "G3")
top3
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 338     GP   F   17       R     LE3       T     3     1  services    other
# 636     MS   M   18       U     GT3       T     4     4   teacher  teacher
# 113     GP   M   15       U     LE3       T     4     2   teacher    other
#
#      ... goout Dalc  Walc  health  absences  G1  G2  G3    Average Total Marks
# 338  ...     2    1     1       3         0  18  19  19  18.666667          56
# 636  ...     4    1     4       2         4  17  18  19  18.000000          54
# 113  ...     2    1     1       3        10  18  17  18  17.666667          53
#
# [3 rows x 35 columns]

# %% [markdown]
# FIND THE BOTTOM 3 STUDENTS

# %%
bottom3 = df.nsmallest(3, "G3")
bottom3
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 163     GP   M   18       U     LE3       T     1     1    other     other
# 440     MS   M   16       U     GT3       T     1     1  at_home  services
# 519     MS   M   16       R     GT3       T     2     1    other  services
#
#      ... goout Dalc  Walc  health  absences  G1 G2 G3   Average Total Marks
# 163  ...     5    2     5       4         0  11  9  0  6.666667          20
# 440  ...     5    4     5       3         0   7  0  0  2.333333           7
# 519  ...     1    1     1       2         0   8  7  0  5.000000          15
#
# [3 rows x 35 columns]

# %% [markdown]
# Find the students who go out frequently

# %%
goout = df[df["goout"] >= 4]
goout
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 15      GP   F   16       U     GT3       T     4     4    health     other
# 18      GP   M   17       U     GT3       T     3     2  services  services
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 635     MS   F   17       R     GT3       T     3     1   at_home     other
# 636     MS   M   18       U     GT3       T     4     4   teacher   teacher
# 642     MS   F   17       U     GT3       T     4     3   teacher     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 647     MS   M   17       U     LE3       T     3     1  services  services
#
# ...
