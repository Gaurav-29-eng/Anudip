# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaurav-29-eng/Anudip/blob/main/POPULAR_MOVIES_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-33a5e1a4-7ca6-4c16-9e0d-26e851104940" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-33a5e1a4-7ca6-4c16-9e0d-26e851104940">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 1. Load the dataset.

# %%
import pandas as pd

df = pd.read_csv("popular-movies.csv")

# %%
df.head()
# Out:
#               title  year   revenue     imdb_id  tmdb_id  trakt_id
# 0           Hoppers  2026  29000000  tt26443616  1327819   1085761
# 1  Reminders of Him  2026  18000000  tt33714084  1367642   1116720
# 2         undertone  2026   9300000  tt35892608  1480387   1213506
# 3          Scream 7  2026   8400000  tt27047903  1159559    934134
# 4              GOAT  2026   4700000  tt27613895  1297842   1057839

# %% [markdown]
# 2. Display the first 10 rows.

# %%
df.head(10)
# Out:
#                                                title  year   revenue  \
# 0                                            Hoppers  2026  29000000
# 1                                   Reminders of Him  2026  18000000
# 2                                          undertone  2026   9300000
# 3                                           Scream 7  2026   8400000
# 4                                               GOAT  2026   4700000
# 5                                         The Bride!  2026   2100000
# 6                            Kiki's Delivery Service  1989   1700000
# 7                                "Wuthering Heights"  2026   1700000
# 8  Teenage Mutant Ninja Turtles II: The Secret of...  1991   1500000
# 9                                          Crime 101  2026   1100000
#
#       imdb_id  tmdb_id  trakt_id
# 0  tt26443616  1327819   1085761
# 1  tt33714084  1367642   1116720
# 2  tt35892608  1480387   1213506
# 3  tt27047903  1159559    934134
# 4  tt27613895  1297842   1057839
# ...

# %%
df.tail()
# Out:
#                                                  title  year  revenue  \
# 995                                         The Bride!  2026  2100000
# 996                            Kiki's Delivery Service  1989  1700000
# 997                                "Wuthering Heights"  2026  1700000
# 998  Teenage Mutant Ninja Turtles II: The Secret of...  1991  1500000
# 999                                          Crime 101  2026  1100000
#
#         imdb_id  tmdb_id  trakt_id
# 995  tt30851137  1159831    934595
# 996   tt0097814    16859     10314
# 997  tt32897959  1316092   1077273
# 998   tt0103060     1497       991
# 999  tt32430579  1171145    944042

# %% [markdown]
# 3. Display the last 10 rows.

# %%
df.tail(10)
# Out:
#                                                  title  year   revenue  \
# 990                                            Hoppers  2026  29000000
# 991                                   Reminders of Him  2026  18000000
# 992                                          undertone  2026   9300000
# 993                                           Scream 7  2026   8400000
# 994                                               GOAT  2026   4700000
# 995                                         The Bride!  2026   2100000
# 996                            Kiki's Delivery Service  1989   1700000
# 997                                "Wuthering Heights"  2026   1700000
# 998  Teenage Mutant Ninja Turtles II: The Secret of...  1991   1500000
# 999                                          Crime 101  2026   1100000
#
#         imdb_id  tmdb_id  trakt_id
# 990  tt26443616  1327819   1085761
# 991  tt33714084  1367642   1116720
# 992  tt35892608  1480387   1213506
# 993  tt27047903  1159559    934134
# ...

# %% [markdown]
# 4. Find the number of rows and columns.

# %%
df.shape
# Out:
# (1000, 6)

# %% [markdown]
# 5. Print all column names.

# %%
df.columns
# Out:
# Index(['title', 'year', 'revenue', 'imdb_id', 'tmdb_id', 'trakt_id'], dtype='object')

# %% [markdown]
# 6. Display data types.

# %%
df.dtypes
# Out:
# title       object
# year         int64
# revenue      int64
# imdb_id     object
# tmdb_id      int64
# trakt_id     int64
# dtype: object

# %% [markdown]
# 7. Display dataset information.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     1000 non-null   object
#  1   year      1000 non-null   int64
#  2   revenue   1000 non-null   int64
#  3   imdb_id   1000 non-null   object
#  4   tmdb_id   1000 non-null   int64
#  5   trakt_id  1000 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 47.0+ KB

# %% [markdown]
# 8. Generate descriptive statistics.

# %%
df.describe()
# Out:
#               year       revenue       tmdb_id      trakt_id
# count  1000.000000  1.000000e+03  1.000000e+03  1.000000e+03
# mean   2018.800000  7.750000e+06  1.029867e+06  8.375175e+05
# std      14.414152  8.705877e+06  5.195836e+05  4.246083e+05
# min    1989.000000  1.100000e+06  1.497000e+03  9.910000e+02
# 25%    2026.000000  1.700000e+06  1.159559e+06  9.341340e+05
# 50%    2026.000000  3.400000e+06  1.234494e+06  1.000940e+06
# 75%    2026.000000  9.300000e+06  1.327819e+06  1.085761e+06
# max    2026.000000  2.900000e+07  1.480387e+06  1.213506e+06

# %%
df.sample()
# Out:
#         title  year  revenue     imdb_id  tmdb_id  trakt_id
# 243  Scream 7  2026  8400000  tt27047903  1159559    934134

# %%
df.sample(6)
# Out:
#                                                  title  year   revenue  \
# 513                                           Scream 7  2026   8400000
# 548  Teenage Mutant Ninja Turtles II: The Secret of...  1991   1500000
# 235                                         The Bride!  2026   2100000
# 325                                         The Bride!  2026   2100000
# 220                                            Hoppers  2026  29000000
# 193                                           Scream 7  2026   8400000
#
#         imdb_id  tmdb_id  trakt_id
# 513  tt27047903  1159559    934134
# 548   tt0103060     1497       991
# 235  tt30851137  1159831    934595
# 325  tt30851137  1159831    934595
# 220  tt26443616  1327819   1085761
# 193  tt27047903  1159559    934134

# %%
df.isnull()
# Out:
#      title   year  revenue  imdb_id  tmdb_id  trakt_id
# 0    False  False    False    False    False     False
# 1    False  False    False    False    False     False
# 2    False  False    False    False    False     False
# 3    False  False    False    False    False     False
# 4    False  False    False    False    False     False
# ..     ...    ...      ...      ...      ...       ...
# 995  False  False    False    False    False     False
# 996  False  False    False    False    False     False
# 997  False  False    False    False    False     False
# 998  False  False    False    False    False     False
# 999  False  False    False    False    False     False
#
# [1000 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# title       0
# year        0
# revenue     0
# imdb_id     0
# tmdb_id     0
# trakt_id    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Length: 1000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(990)

# %%
df["title"].unique()
# Out:
# array(['Hoppers', 'Reminders of Him', 'undertone', 'Scream 7', 'GOAT',
#        'The Bride!', "Kiki's Delivery Service", '"Wuthering Heights"',
#        'Teenage Mutant Ninja Turtles II: The Secret of the Ooze',
#        'Crime 101'], dtype=object)

# %%
df["title"].nunique()
# Out:
# 10

# %%
df["year"].value_counts()
# Out:
# year
# 2026    800
# 1989    100
# 1991    100
# Name: count, dtype: int64

# %%
df["revenue"]
# Out:
# 0      29000000
# 1      18000000
# 2       9300000
# 3       8400000
# 4       4700000
#          ...
# 995     2100000
# 996     1700000
# 997     1700000
# 998     1500000
# 999     1100000
# Name: revenue, Length: 1000, dtype: int64

# %%
df[["title","revenue"]]
# Out:
#                                                  title   revenue
# 0                                              Hoppers  29000000
# 1                                     Reminders of Him  18000000
# 2                                            undertone   9300000
# 3                                             Scream 7   8400000
# 4                                                 GOAT   4700000
# ..                                                 ...       ...
# 995                                         The Bride!   2100000
# 996                            Kiki's Delivery Service   1700000
# 997                                "Wuthering Heights"   1700000
# 998  Teenage Mutant Ninja Turtles II: The Secret of...   1500000
# 999                                          Crime 101   1100000
#
# [1000 rows x 2 columns]

# %%
df[df["revenue"] > 1100000]
# Out:
#                                                  title  year   revenue  \
# 0                                              Hoppers  2026  29000000
# 1                                     Reminders of Him  2026  18000000
# 2                                            undertone  2026   9300000
# 3                                             Scream 7  2026   8400000
# 4                                                 GOAT  2026   4700000
# ..                                                 ...   ...       ...
# 994                                               GOAT  2026   4700000
# 995                                         The Bride!  2026   2100000
# 996                            Kiki's Delivery Service  1989   1700000
# 997                                "Wuthering Heights"  2026   1700000
# 998  Teenage Mutant Ninja Turtles II: The Secret of...  1991   1500000
#
#         imdb_id  tmdb_id  trakt_id
# 0    tt26443616  1327819   1085761
# 1    tt33714084  1367642   1116720
# ...

# %%
df["imdb_id"].max()
# Out:
# 'tt35892608'

# %%
df["tmdb_id"].min()
# Out:
# 1497

# %%
df["revenue"].median()
# Out:
# 3400000.0

# %%
df["trakt_id"].mean()
# Out:
# np.float64(837517.5)

# %%
df.sort_values(by="revenue")
# Out:
#          title  year   revenue     imdb_id  tmdb_id  trakt_id
# 999  Crime 101  2026   1100000  tt32430579  1171145    944042
# 19   Crime 101  2026   1100000  tt32430579  1171145    944042
# 969  Crime 101  2026   1100000  tt32430579  1171145    944042
# 29   Crime 101  2026   1100000  tt32430579  1171145    944042
# 939  Crime 101  2026   1100000  tt32430579  1171145    944042
# ..         ...   ...       ...         ...      ...       ...
# 10     Hoppers  2026  29000000  tt26443616  1327819   1085761
# 930    Hoppers  2026  29000000  tt26443616  1327819   1085761
# 240    Hoppers  2026  29000000  tt26443616  1327819   1085761
# 0      Hoppers  2026  29000000  tt26443616  1327819   1085761
# 210    Hoppers  2026  29000000  tt26443616  1327819   1085761
#
# [1000 rows x 6 columns]

# %%
df.sort_values(by="revenue",ascending=False)
# Out:
#          title  year   revenue     imdb_id  tmdb_id  trakt_id
# 970    Hoppers  2026  29000000  tt26443616  1327819   1085761
# 960    Hoppers  2026  29000000  tt26443616  1327819   1085761
# 20     Hoppers  2026  29000000  tt26443616  1327819   1085761
# 30     Hoppers  2026  29000000  tt26443616  1327819   1085761
# 930    Hoppers  2026  29000000  tt26443616  1327819   1085761
# ..         ...   ...       ...         ...      ...       ...
# 519  Crime 101  2026   1100000  tt32430579  1171145    944042
# 509  Crime 101  2026   1100000  tt32430579  1171145    944042
# 129  Crime 101  2026   1100000  tt32430579  1171145    944042
# 949  Crime 101  2026   1100000  tt32430579  1171145    944042
# 959  Crime 101  2026   1100000  tt32430579  1171145    944042
#
# [1000 rows x 6 columns]
